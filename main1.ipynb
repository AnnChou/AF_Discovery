# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from model import *
from data import *
from CustomeDataGenerator import  CustomDataGenerator

# %%
# %cd drive/My Drive/unet-master
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/unet-master'
# /content

# %%
train_path = 'Training-Splitted/train/'
val_path = 'Training-Splitted/val/'
batch_size = 32
dim = [540,800,3]
n_channels = 1

# using custom datagenerator:
train_gen =CustomDataGenerator(path = train_path, batch_size = batch_size, dim = dim, n_channels = n_channels, shuffle = True, augmentation = True)
val_gen =CustomDataGenerator(path = val_path, batch_size = batch_size, dim = dim, n_channels = n_channels, shuffle = True, augmentation = True)




model = unet()
model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit(train_gen, validation_data=val_gen ,steps_per_epoch=1,epochs=5,callbacks=[model_checkpoint])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ea6fa658c398> in <cell line: 16>()
#      14 model = unet()
#      15 model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
# ---> 16 model.fit(train_gen, validation_data=val_gen ,steps_per_epoch=300,epochs=1,callbacks=[model_checkpoint])
#      17
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ...

# %%
testGene = testGenerator("Training_Splitted/test") # I don't think this needs to be changed (the function does not use ImageDataGenerator nor augmentations)
results = model.predict_generator(testGene,30,verbose=1)
saveResult("Training_Splitted/test",results)

# %%
from model import *
from data import *
